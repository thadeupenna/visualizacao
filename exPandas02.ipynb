# %% [markdown]
# <a href="https://colab.research.google.com/github/thadeupenna/visualizacao/blob/master/exPandas02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Leia o arquivo do questionário do minicurso. Faça um histograma de frequencia dos locais de origem dos inscritos.
